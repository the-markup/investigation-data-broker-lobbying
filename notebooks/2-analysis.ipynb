# %%
import xml.etree.ElementTree as ET
import json
import glob
import re
from pathlib import Path

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('../data/matching_process/filings.json', 'r') as json_file:
    data = json.load(json_file)

df = pd.read_csv('../data/findings/data-broker-filings.csv')

# %% [markdown]
# Create a key to match subsidiaries with their parent companies

# %%
subsidiaries_df = df[~df['parent_company'].isna()][['parent_company', 'company']].drop_duplicates().copy()
subsidiaries = pd.Series(subsidiaries_df.parent_company.values,index=subsidiaries_df.company).to_dict()

# %% [markdown]
# ## Spending

# %%
period_spending = df.groupby(['company', 'period', 'is_self_filer']).sum().reset_index().copy()

# %%
period_spending = period_spending.sort_values(by='is_self_filer', ascending=False).drop_duplicates(subset=['company', 'period'])

# %%
period_spending
# Out:
#                     company                         period  is_self_filer  \
# 87                   ORACLE   1st Quarter (Jan 1 - Mar 31)           True
# 103  PRICEWATERHOUSECOOPERS  3rd Quarter (July 1 - Sep 30)           True
# 105  PRICEWATERHOUSECOOPERS   4th Quarter (Oct 1 - Dec 31)           True
# 129              S&P GLOBAL   4th Quarter (Oct 1 - Dec 31)           True
# 50                  EQUIFAX  2nd Quarter (Apr 1 - June 30)           True
# ..                      ...                            ...            ...
# 63               IHS MARKIT   1st Quarter (Jan 1 - Mar 31)          False
# 46                 ELSEVIER   4th Quarter (Oct 1 - Dec 31)          False
# 45                 ELSEVIER  3rd Quarter (July 1 - Sep 30)          False
# 44                 ELSEVIER  2nd Quarter (Apr 1 - June 30)          False
# 146             ZETA GLOBAL   4th Quarter (Oct 1 - Dec 31)          False
#
#       spending
# 87   1890000.0
# 103   730000.0
# 105   690000.0
# 129   370000.0
# 50    350000.0
# ..         ...
# 63     20000.0
# 46     10000.0
# 45     30000.0
# 44     20000.0
# 146    50000.0
#
# [103 rows x 4 columns]

# %%
period_spending['company'] = period_spending['company'].apply(lambda x: x if not x in subsidiaries.keys() else subsidiaries[x])

# %%
total_period_spending = period_spending[['company','period','spending']].groupby(['company', 'period']).sum().sort_values(by=['company', 'period']).copy()

# %%
ttl = total_period_spending.reset_index().pivot('company', 'period').reset_index()

# %%
ttl['2020 Spending'] = ttl.sum(axis=1)

# %%
ttl = ttl.sort_values(by='2020 Spending', ascending=False)

# %% [markdown]
# Export Spending

# %%
ttl.columns = [b if a =="spending" else a for (a, b) in ttl.columns]

# %%
ttl.to_csv('../data/findings/period-spending.csv', index=False)

# %% [markdown]
# ## Issues

# %%
d = []
for f in data['Filings']:
    if f['ID'] in df['filing_id'].unique() and f.get('Issues'):
        for issue in f.get('Issues'):
            d.append({
                'filing.id': f['ID'],
                'category': issue['Code'],
                'issue': issue['SpecificIssue']
            })
issues = pd.DataFrame(d)

# %%
issues['cleaned'] = issues.issue.str.lower()
issues['hr_bills'] = issues['cleaned'].str.findall('h\.?r\.? ?\d*')
issues['s_bills'] = issues['cleaned'].str.findall('s\. ?\d*')

# %%
issues
# Out:
#                                 filing.id  \
# 0    62AEECD8-DF4E-487B-9BDF-987863110E53
# 1    8636186A-DC3F-40E9-B54D-9F236760075F
# 2    B4D3FEE4-BF23-4A97-A904-6CE4C970B92B
# 3    F2965A17-6CA6-4338-97F2-19C4C9188C13
# 4    F2965A17-6CA6-4338-97F2-19C4C9188C13
# ..                                    ...
# 957  285C9DF5-8104-4737-8516-0CB0878558B2
# 958  285C9DF5-8104-4737-8516-0CB0878558B2
# 959  285C9DF5-8104-4737-8516-0CB0878558B2
# 960  43A31771-752F-4F82-97F9-A255BEA23D0D
# 961  43A31771-752F-4F82-97F9-A255BEA23D0D
#
#                                           category  \
# 0                                COMPUTER INDUSTRY
# 1                  CONSUMER ISSUES/SAFETY/PRODUCTS
# 2                               TELECOMMUNICATIONS
# 3                               TELECOMMUNICATIONS
# 4                                COMPUTER INDUSTRY
# ..                                             ...
# 957                                  HEALTH ISSUES
# 958                             SCIENCE/TECHNOLOGY
# 959  FINANCIAL INSTITUTIONS/INVESTMENTS/SECURITIES
# 960                          BUDGET/APPROPRIATIONS
# 961                              GOVERNMENT ISSUES
#
#                                                  issue  \
# 0    Monitoring Congressional activities regarding ...
# 1                     Issues surrounding data privacy.
# 2                                  General tech issues
# 3    Issues related to robocalling, the Telephone C...
# 4    Issues relating to Internet Governance, ICANN,...
# ..                                                 ...
# 957                       Issues related to healthcare
# 958                       Issues related to technology
# 959               Issues related to financial services
# 960  Use of commercial data by federal government a...
# 961  Use of commercial data by federal government a...
#
#                                                cleaned    hr_bills s_bills
# 0    monitoring congressional activities regarding ...          []      []
# 1                     issues surrounding data privacy.          []      []
# 2                                  general tech issues          []      []
# 3    issues related to robocalling, the telephone c...    [hr 946]      []
# 4    issues relating to internet governance, icann,...          []    [s.]
# ..                                                 ...         ...     ...
# 957                       issues related to healthcare          []      []
# 958                       issues related to technology          []      []
# 959               issues related to financial services          []      []
# 960  use of commercial data by federal government a...          []    [s.]
# 961  use of commercial data by federal government a...  [h.r.3941]      []
#
# [962 rows x 6 columns]

# %%
def find_number(text):
    num = re.findall(r'[0-9]+',text)
    number = "".join(num)
    if len(number) > 0:
        return int(number)
    return np.nan

# %%
issues['hr_bills'] = issues['hr_bills'].apply(lambda l: [find_number(x) for x in l])
issues['hr_bills'] = issues['hr_bills'].apply(lambda l: np.nan if len(l) == 0 else l)

issues['s_bills'] = issues['s_bills'].apply(lambda l: [find_number(x) for x in l])
issues['s_bills'] = issues['s_bills'].apply(lambda l: np.nan if len(l) == 0 else l)

issues['hr_bills'] = issues['hr_bills'].apply(lambda l: list(set(l)) if isinstance(l,list) and (len(l) > 0) else np.nan)
issues['s_bills'] = issues['s_bills'].apply(lambda l: list(set(l)) if isinstance(l,list) and (len(l) > 0) else np.nan)

# %%
issues['cleaned'] = issues['cleaned'].str.replace('issues related to', '')
issues['cleaned'] = issues['cleaned'].str.replace('issues relating to', '')
issues['cleaned'] = issues['cleaned'].str.replace('issues surrounding', '')

# %%
company_issues = issues.merge(df[['filing_id', 'company', 'lobbying_firm', 'period']], left_on='filing.id', right_on='filing_id')
company_issues['company'] = company_issues['company'].apply(lambda x: x if not x in subsidiaries.keys() else subsidiaries[x])

# %%
company_issues
# Out:
#                                 filing.id  \
# 0    62AEECD8-DF4E-487B-9BDF-987863110E53
# 1    8636186A-DC3F-40E9-B54D-9F236760075F
# 2    B4D3FEE4-BF23-4A97-A904-6CE4C970B92B
# 3    F2965A17-6CA6-4338-97F2-19C4C9188C13
# 4    F2965A17-6CA6-4338-97F2-19C4C9188C13
# ..                                    ...
# 957  285C9DF5-8104-4737-8516-0CB0878558B2
# 958  285C9DF5-8104-4737-8516-0CB0878558B2
# 959  285C9DF5-8104-4737-8516-0CB0878558B2
# 960  43A31771-752F-4F82-97F9-A255BEA23D0D
# 961  43A31771-752F-4F82-97F9-A255BEA23D0D
#
#                                           category  \
# 0                                COMPUTER INDUSTRY
# 1                  CONSUMER ISSUES/SAFETY/PRODUCTS
# 2                               TELECOMMUNICATIONS
# 3                               TELECOMMUNICATIONS
# 4                                COMPUTER INDUSTRY
# ..                                             ...
# 957                                  HEALTH ISSUES
# 958                             SCIENCE/TECHNOLOGY
# 959  FINANCIAL INSTITUTIONS/INVESTMENTS/SECURITIES
# 960                          BUDGET/APPROPRIATIONS
# 961                              GOVERNMENT ISSUES
#
#                                                  issue  \
# 0    Monitoring Congressional activities regarding ...
# 1                     Issues surrounding data privacy.
# 2                                  General tech issues
# 3    Issues related to robocalling, the Telephone C...
# 4    Issues relating to Internet Governance, ICANN,...
# ..                                                 ...
# 957                       Issues related to healthcare
# 958                       Issues related to technology
# 959               Issues related to financial services
# 960  Use of commercial data by federal government a...
# 961  Use of commercial data by federal government a...
#
#                                                cleaned hr_bills s_bills  \
# 0    monitoring congressional activities regarding ...      NaN     NaN
# 1                                        data privacy.      NaN     NaN
# 2                                  general tech issues      NaN     NaN
# 3     robocalling, the telephone consumer protectio...    [946]     NaN
# 4     internet governance, icann, domain name regis...      NaN   [nan]
# ..                                                 ...      ...     ...
# 957                                         healthcare      NaN     NaN
# 958                                         technology      NaN     NaN
# 959                                 financial services      NaN     NaN
# 960  use of commercial data by federal government a...      NaN   [nan]
# 961  use of commercial data by federal government a...   [3941]     NaN
#
#                                 filing_id     company  \
# 0    62AEECD8-DF4E-487B-9BDF-987863110E53      ORACLE
# 1    8636186A-DC3F-40E9-B54D-9F236760075F    LIVERAMP
# 2    B4D3FEE4-BF23-4A97-A904-6CE4C970B92B      ORACLE
# 3    F2965A17-6CA6-4338-97F2-19C4C9188C13     NEUSTAR
# 4    F2965A17-6CA6-4338-97F2-19C4C9188C13     NEUSTAR
# ..                                    ...         ...
# 957  285C9DF5-8104-4737-8516-0CB0878558B2  TRANSUNION
# 958  285C9DF5-8104-4737-8516-0CB0878558B2  TRANSUNION
# 959  285C9DF5-8104-4737-8516-0CB0878558B2  TRANSUNION
# 960  43A31771-752F-4F82-97F9-A255BEA23D0D     EQUIFAX
# 961  43A31771-752F-4F82-97F9-A255BEA23D0D     EQUIFAX
#
#                                lobbying_firm                         period
# 0                  The Michael Lewan Company   1st Quarter (Jan 1 - Mar 31)
# 1                          The Madison Group  2nd Quarter (Apr 1 - June 30)
# 2                            Cove Strategies  2nd Quarter (Apr 1 - June 30)
# 3    Perry Bayliss Government Relations, LLC  2nd Quarter (Apr 1 - June 30)
# 4    Perry Bayliss Government Relations, LLC  2nd Quarter (Apr 1 - June 30)
# ..                                       ...                            ...
# 957      Subject Matter (fka Elmendorf Ryan)   4th Quarter (Oct 1 - Dec 31)
# 958      Subject Matter (fka Elmendorf Ryan)   4th Quarter (Oct 1 - Dec 31)
# 959      Subject Matter (fka Elmendorf Ryan)   4th Quarter (Oct 1 - Dec 31)
# 960              ATRIO CONSULTING GROUP, LLC   4th Quarter (Oct 1 - Dec 31)
# 961              ATRIO CONSULTING GROUP, LLC   4th Quarter (Oct 1 - Dec 31)
#
# [962 rows x 10 columns]
